# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
#     print(city_url)
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

#     Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | half moon bay
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | luna
# Processing Record 6 of Set 1 | quatre cocos
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | kuito
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | tateyama
# Processing Record 16 of Set 1 | luanda
# Processing Record 17 of Set 1 | zeya
# Processing Record 18 of Set 1 | teacapan
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | kapoeta
# Processing Record 21 of Set 1 | isangel
# Processing Record 22 of Set 1 | port-cartier
# Processing Record 23 of Set 1 | awbari
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | roma
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | sinnamary
# Processing Record 30 of Set 1 | obo
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | peniche
# Processing Record 33 of Set 1 | lorengau
# Processing Record 34 of Set 1 | cubuk
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | abashiri
# Processing Record 38 of Set 1 | sharjah
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | lagoa
# Processing Record 42 of Set 1 | benguela
# Processing Record 43 of Set 1 | port lincoln
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | soto la marina
# Processing Record 46 of Set 1 | watertown
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | ozinki
# Processing Record 49 of Set 1 | saravena
# Processing Record 50 of Set 1 | calvinia
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | ancud
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | balabac
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | narasannapeta
# Processing Record 10 of Set 2 | mayumba
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | progreso
# Processing Record 13 of Set 2 | soyo
# Processing Record 14 of Set 2 | fortuna
# Processing Record 15 of Set 2 | temerloh
# Processing Record 16 of Set 2 | umm bab
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | champoton
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 2 | krasnoselkup
# Processing Record 25 of Set 2 | wanning
# Processing Record 26 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 2 | tabulbah
# City not found. Skipping...
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | rangapara
# Processing Record 30 of Set 2 | vardo
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | tessalit
# Processing Record 33 of Set 2 | nkowakowa
# Processing Record 34 of Set 2 | yumen
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | encheng
# Processing Record 39 of Set 2 | leh
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | ahuimanu
# Processing Record 42 of Set 2 | mishelevka
# Processing Record 43 of Set 2 | general roca
# Processing Record 44 of Set 2 | mouzakion
# City not found. Skipping...
# Processing Record 45 of Set 2 | hovd
# Processing Record 46 of Set 2 | mossendjo
# Processing Record 47 of Set 2 | matagami
# Processing Record 48 of Set 2 | santa marinella
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 3 | te anau
# Processing Record 2 of Set 3 | bac lieu
# Processing Record 3 of Set 3 | venado tuerto
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | shimoda
# Processing Record 6 of Set 3 | sidmouth
# Processing Record 7 of Set 3 | bandarbeyla
# Processing Record 8 of Set 3 | nioro
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | the valley
# Processing Record 11 of Set 3 | honiara
# Processing Record 12 of Set 3 | kabwe
# Processing Record 13 of Set 3 | lae
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | sao geraldo do araguaia
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | mogadishu
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | shu
# Processing Record 25 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | okhotsk
# Processing Record 27 of Set 3 | mount isa
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | zverinogolovskoye
# Processing Record 31 of Set 3 | dingle
# Processing Record 32 of Set 3 | luena
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | camacupa
# Processing Record 36 of Set 3 | grindavik
# Processing Record 37 of Set 3 | abha
# Processing Record 38 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | avera
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | japura
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | savannah bight
# Processing Record 47 of Set 3 | yuty
# Processing Record 48 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 49 of Set 3 | purpe
# Processing Record 50 of Set 3 | jiaocheng
# Processing Record 1 of Set 4 | hami
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | ahipara
# Processing Record 4 of Set 4 | ode
# Processing Record 5 of Set 4 | stornoway
# Processing Record 6 of Set 4 | carnarvon
# Processing Record 7 of Set 4 | vilhena
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | ugoofaaru
# Processing Record 10 of Set 4 | alofi
# Processing Record 11 of Set 4 | ambovombe
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | belyy yar
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | ignacio de la llave
# Processing Record 18 of Set 4 | key west
# Processing Record 19 of Set 4 | gat
# Processing Record 20 of Set 4 | tingo maria
# Processing Record 21 of Set 4 | sobolevo
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | wadi maliz
# Processing Record 24 of Set 4 | ixtapa
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | inuvik
# Processing Record 27 of Set 4 | sabang
# Processing Record 28 of Set 4 | flinders
# Processing Record 29 of Set 4 | padang
# Processing Record 30 of Set 4 | guerrero negro
# Processing Record 31 of Set 4 | bonthe
# Processing Record 32 of Set 4 | chaa-khol
# City not found. Skipping...
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | kilis
# Processing Record 36 of Set 4 | broome
# Processing Record 37 of Set 4 | tawang
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | baruun-urt
# Processing Record 40 of Set 4 | vilyuysk
# Processing Record 41 of Set 4 | senno
# Processing Record 42 of Set 4 | sfantu gheorghe
# Processing Record 43 of Set 4 | quelimane
# Processing Record 44 of Set 4 | taoudenni
# Processing Record 45 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | dikson
# Processing Record 48 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 4 | vanavara
# Processing Record 50 of Set 4 | namatanai
# Processing Record 1 of Set 5 | san joaquin
# Processing Record 2 of Set 5 | sur
# Processing Record 3 of Set 5 | rio grande
# Processing Record 4 of Set 5 | miri
# Processing Record 5 of Set 5 | bathsheba
# Processing Record 6 of Set 5 | saldanha
# Processing Record 7 of Set 5 | nyurba
# Processing Record 8 of Set 5 | itaituba
# Processing Record 9 of Set 5 | sabha
# Processing Record 10 of Set 5 | barrow
# Processing Record 11 of Set 5 | ostersund
# Processing Record 12 of Set 5 | chatra
# Processing Record 13 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | bowling green
# Processing Record 15 of Set 5 | qaanaaq
# Processing Record 16 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 5 | sikasso
# Processing Record 18 of Set 5 | la crosse
# Processing Record 19 of Set 5 | toppenish
# Processing Record 20 of Set 5 | ngunguru
# Processing Record 21 of Set 5 | souillac
# Processing Record 22 of Set 5 | biak
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | port-gentil
# Processing Record 25 of Set 5 | muros
# Processing Record 26 of Set 5 | la ronge
# Processing Record 27 of Set 5 | kushima
# Processing Record 28 of Set 5 | longonjo
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | ust-tsilma
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | caucaia
# Processing Record 33 of Set 5 | luganville
# Processing Record 34 of Set 5 | bodaybo
# Processing Record 35 of Set 5 | san lazaro
# Processing Record 36 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 5 | amapa
# Processing Record 38 of Set 5 | ngama
# Processing Record 39 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 5 | tomatlan
# Processing Record 41 of Set 5 | ustye
# Processing Record 42 of Set 5 | kovur
# Processing Record 43 of Set 5 | whitianga
# Processing Record 44 of Set 5 | ferrol
# Processing Record 45 of Set 5 | vao
# Processing Record 46 of Set 5 | mariinskiy posad
# Processing Record 47 of Set 5 | hervey bay
# Processing Record 48 of Set 5 | canutama
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | saskylakh
# Processing Record 1 of Set 6 | carutapera
# Processing Record 2 of Set 6 | tapiramuta
# Processing Record 3 of Set 6 | kurumkan
# Processing Record 4 of Set 6 | oktyabrskiy
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 6 | puri
# Processing Record 8 of Set 6 | chowchilla
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | camacha
# Processing Record 11 of Set 6 | tamiahua
# Processing Record 12 of Set 6 | omsukchan
# Processing Record 13 of Set 6 | mandera
# Processing Record 14 of Set 6 | seoni malwa
# Processing Record 15 of Set 6 | mar del plata
# Processing Record 16 of Set 6 | cockburn town
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | vestmannaeyjar
# Processing Record 19 of Set 6 | grand gaube
# Processing Record 20 of Set 6 | sakakah
# Processing Record 21 of Set 6 | chemal
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | lebu
# Processing Record 24 of Set 6 | longyearbyen
# Processing Record 25 of Set 6 | otradnoye
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | riedlingen
# Processing Record 28 of Set 6 | dahegam
# Processing Record 29 of Set 6 | la sarre
# Processing Record 30 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | caravelas
# Processing Record 33 of Set 6 | hobart
# Processing Record 34 of Set 6 | winslow
# Processing Record 35 of Set 6 | sangar
# Processing Record 36 of Set 6 | ossora
# Processing Record 37 of Set 6 | lat yao
# Processing Record 38 of Set 6 | praia
# Processing Record 39 of Set 6 | zhanakorgan
# Processing Record 40 of Set 6 | raudeberg
# Processing Record 41 of Set 6 | saint andrews
# Processing Record 42 of Set 6 | la palma
# Processing Record 43 of Set 6 | fort nelson
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | mecca
# Processing Record 46 of Set 6 | swinford
# Processing Record 47 of Set 6 | huilong
# Processing Record 48 of Set 6 | khatanga
# Processing Record 49 of Set 6 | vera cruz
# Processing Record 50 of Set 6 | khorixas
# Processing Record 1 of Set 7 | gravdal
# Processing Record 2 of Set 7 | jiehu
# Processing Record 3 of Set 7 | hualmay
# Processing Record 4 of Set 7 | saint george
# Processing Record 5 of Set 7 | dawei
# Processing Record 6 of Set 7 | pitimbu
# Processing Record 7 of Set 7 | ubata
# Processing Record 8 of Set 7 | pau
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | faanui
# Processing Record 11 of Set 7 | millbrook
# Processing Record 12 of Set 7 | nathdwara
# Processing Record 13 of Set 7 | san ignacio
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 7 | north platte
# Processing Record 17 of Set 7 | leningradskiy
# Processing Record 18 of Set 7 | shangrao
# Processing Record 19 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 7 | sao filipe
# Processing Record 21 of Set 7 | rio gallegos
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | xinmin
# Processing Record 24 of Set 7 | vaovai
# City not found. Skipping...
# Processing Record 25 of Set 7 | makakilo city
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | mnogovershinnyy
# Processing Record 28 of Set 7 | pyay
# Processing Record 29 of Set 7 | richards bay
# Processing Record 30 of Set 7 | yankton
# Processing Record 31 of Set 7 | sile
# Processing Record 32 of Set 7 | galesong
# Processing Record 33 of Set 7 | shache
# Processing Record 34 of Set 7 | marzuq
# Processing Record 35 of Set 7 | mayo
# Processing Record 36 of Set 7 | saint-michel-des-saints
# Processing Record 37 of Set 7 | bogovarovo
# Processing Record 38 of Set 7 | kanniyakumari
# Processing Record 39 of Set 7 | igarka
# Processing Record 40 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 41 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 7 | garden city
# Processing Record 43 of Set 7 | aktau
# Processing Record 44 of Set 7 | mehamn
# Processing Record 45 of Set 7 | olafsvik
# Processing Record 46 of Set 7 | berlevag
# Processing Record 47 of Set 7 | anda
# Processing Record 48 of Set 7 | seoul
# Processing Record 49 of Set 7 | turukhansk
# Processing Record 50 of Set 7 | chulym
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | touros
# Processing Record 3 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 8 | abnub
# Processing Record 5 of Set 8 | namibe
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | navoi
# Processing Record 8 of Set 8 | kruisfontein
# Processing Record 9 of Set 8 | kushmurun
# Processing Record 10 of Set 8 | staroshcherbinovskaya
# Processing Record 11 of Set 8 | gonda
# Processing Record 12 of Set 8 | buraydah
# Processing Record 13 of Set 8 | dwarka
# Processing Record 14 of Set 8 | arlit
# Processing Record 15 of Set 8 | hue
# Processing Record 16 of Set 8 | salamanca
# Processing Record 17 of Set 8 | hecun
# Processing Record 18 of Set 8 | vanimo
# Processing Record 19 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 8 | sorland
# Processing Record 21 of Set 8 | henties bay
# Processing Record 22 of Set 8 | meulaboh
# Processing Record 23 of Set 8 | manga
# Processing Record 24 of Set 8 | lasa
# Processing Record 25 of Set 8 | auki
# Processing Record 26 of Set 8 | adrar
# Processing Record 27 of Set 8 | eastlake
# Processing Record 28 of Set 8 | garissa
# Processing Record 29 of Set 8 | payo
# Processing Record 30 of Set 8 | pasighat
# Processing Record 31 of Set 8 | hearst
# Processing Record 32 of Set 8 | bontang
# Processing Record 33 of Set 8 | awjilah
# Processing Record 34 of Set 8 | rocha
# Processing Record 35 of Set 8 | kidal
# Processing Record 36 of Set 8 | dinard
# Processing Record 37 of Set 8 | kapit
# Processing Record 38 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 8 | nador
# Processing Record 40 of Set 8 | alugan
# Processing Record 41 of Set 8 | sao felix do xingu
# Processing Record 42 of Set 8 | westport
# Processing Record 43 of Set 8 | nizhniy odes
# Processing Record 44 of Set 8 | port hardy
# Processing Record 45 of Set 8 | jalu
# Processing Record 46 of Set 8 | turkistan
# Processing Record 47 of Set 8 | sitka
# Processing Record 48 of Set 8 | maldonado
# Processing Record 49 of Set 8 | tucupita
# Processing Record 50 of Set 8 | bayanday
# Processing Record 1 of Set 9 | palmares do sul
# Processing Record 2 of Set 9 | mabaruma
# Processing Record 3 of Set 9 | mercedes
# Processing Record 4 of Set 9 | dawlatabad
# Processing Record 5 of Set 9 | norman wells
# Processing Record 6 of Set 9 | aksha
# Processing Record 7 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 9 | dorverden
# Processing Record 9 of Set 9 | wukari
# Processing Record 10 of Set 9 | tazovskiy
# Processing Record 11 of Set 9 | spokoynaya
# Processing Record 12 of Set 9 | bridlington
# Processing Record 13 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 9 | bom jesus
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | balkanabat
# Processing Record 17 of Set 9 | corumba
# Processing Record 18 of Set 9 | saint anthony
# Processing Record 19 of Set 9 | yefremov
# Processing Record 20 of Set 9 | cabra
# Processing Record 21 of Set 9 | rocky mountain house
# Processing Record 22 of Set 9 | kedzierzyn-kozle
# Processing Record 23 of Set 9 | saint-augustin
# Processing Record 24 of Set 9 | kismayo
# Processing Record 25 of Set 9 | augusta
# Processing Record 26 of Set 9 | praia da vitoria
# Processing Record 27 of Set 9 | kahului
# Processing Record 28 of Set 9 | khorramshahr
# Processing Record 29 of Set 9 | coahuayana
# Processing Record 30 of Set 9 | talnakh
# Processing Record 31 of Set 9 | aksarka
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | talcahuano
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | ambilobe
# Processing Record 36 of Set 9 | cabedelo
# Processing Record 37 of Set 9 | sibolga
# Processing Record 38 of Set 9 | nouadhibou
# Processing Record 39 of Set 9 | aberdeen
# Processing Record 40 of Set 9 | beruni
# City not found. Skipping...
# Processing Record 41 of Set 9 | naze
# Processing Record 42 of Set 9 | mrakovo
# Processing Record 43 of Set 9 | kyra
# Processing Record 44 of Set 9 | muisne
# Processing Record 45 of Set 9 | aykhal
# Processing Record 46 of Set 9 | kajaani
# Processing Record 47 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 9 | nuuk
# Processing Record 49 of Set 9 | marion
# Processing Record 50 of Set 9 | williston
# Processing Record 1 of Set 10 | lazaro cardenas
# Processing Record 2 of Set 10 | acapulco
# Processing Record 3 of Set 10 | bastia
# Processing Record 4 of Set 10 | santa cruz
# Processing Record 5 of Set 10 | hohoe
# Processing Record 6 of Set 10 | baiyin
# Processing Record 7 of Set 10 | yamada
# Processing Record 8 of Set 10 | saleilua
# City not found. Skipping...
# Processing Record 9 of Set 10 | kiruna
# Processing Record 10 of Set 10 | thayetmyo
# Processing Record 11 of Set 10 | bakchar
# Processing Record 12 of Set 10 | gushi
# Processing Record 13 of Set 10 | baykit
# Processing Record 14 of Set 10 | livingstone
# Processing Record 15 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 16 of Set 10 | la asuncion
# Processing Record 17 of Set 10 | phangnga
# Processing Record 18 of Set 10 | baykalovo
# Processing Record 19 of Set 10 | pemangkat
# Processing Record 20 of Set 10 | itoman
# Processing Record 21 of Set 10 | swift current
# Processing Record 22 of Set 10 | chapais
# Processing Record 23 of Set 10 | springbok
# Processing Record 24 of Set 10 | mariental
# Processing Record 25 of Set 10 | constantine
# Processing Record 26 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 27 of Set 10 | bay roberts
# Processing Record 28 of Set 10 | yuryevets
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | arman
# Processing Record 31 of Set 10 | shurob
# Processing Record 32 of Set 10 | baie-saint-paul
# Processing Record 33 of Set 10 | akdepe
# Processing Record 34 of Set 10 | sakaiminato
# Processing Record 35 of Set 10 | itarema
# Processing Record 36 of Set 10 | chincha alta
# Processing Record 37 of Set 10 | campbell river
# Processing Record 38 of Set 10 | shahrud
# Processing Record 39 of Set 10 | caborca
# Processing Record 40 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | jiwani
# Processing Record 43 of Set 10 | manicore
# Processing Record 44 of Set 10 | fredericksburg
# Processing Record 45 of Set 10 | lavrentiya
# Processing Record 46 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 10 | camana
# Processing Record 48 of Set 10 | nantucket
# Processing Record 49 of Set 10 | juba
# Processing Record 50 of Set 10 | ust-kuyga
# Processing Record 1 of Set 11 | tura
# Processing Record 2 of Set 11 | kilrush
# Processing Record 3 of Set 11 | kavaratti
# Processing Record 4 of Set 11 | bhaderwah
# Processing Record 5 of Set 11 | svetlogorsk
# Processing Record 6 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 11 | naron
# Processing Record 8 of Set 11 | kaihua
# Processing Record 9 of Set 11 | moron
# Processing Record 10 of Set 11 | mocuba
# Processing Record 11 of Set 11 | laguna
# Processing Record 12 of Set 11 | killybegs
# Processing Record 13 of Set 11 | marabba
# Processing Record 14 of Set 11 | taltal
# Processing Record 15 of Set 11 | kozhva
# Processing Record 16 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 17 of Set 11 | klaksvik
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | bobcaygeon
# Processing Record 20 of Set 11 | sambava
# Processing Record 21 of Set 11 | pattaya
# Processing Record 22 of Set 11 | teahupoo
# Processing Record 23 of Set 11 | boende
# Processing Record 24 of Set 11 | dauphin
# Processing Record 25 of Set 11 | palmer
# Processing Record 26 of Set 11 | gilbert
# Processing Record 27 of Set 11 | riviere-au-renard
# Processing Record 28 of Set 11 | andenes
# Processing Record 29 of Set 11 | hofn
# Processing Record 30 of Set 11 | vila velha
# Processing Record 31 of Set 11 | swan river
# Processing Record 32 of Set 11 | antalaha
# Processing Record 33 of Set 11 | tuatapere
# Processing Record 34 of Set 11 | tamandare
# Processing Record 35 of Set 11 | krasnogvardeyskoye
# Processing Record 36 of Set 11 | benemerito de las americas
# Processing Record 37 of Set 11 | grand island
# Processing Record 38 of Set 11 | najran
# Processing Record 39 of Set 11 | krechevitsy
# Processing Record 40 of Set 11 | russell
# Processing Record 41 of Set 11 | ayr
# Processing Record 42 of Set 11 | adre
# Processing Record 43 of Set 11 | puerto del rosario
# Processing Record 44 of Set 11 | valparaiso
# Processing Record 45 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 46 of Set 11 | loandjili
# Processing Record 47 of Set 11 | beringovskiy
# Processing Record 48 of Set 11 | sisimiut
# Processing Record 49 of Set 11 | nizwa
# Processing Record 50 of Set 11 | maniitsoq
# Processing Record 1 of Set 12 | esperance
# Processing Record 2 of Set 12 | anadyr
# Processing Record 3 of Set 12 | isla vista
# Processing Record 4 of Set 12 | pouebo
# Processing Record 5 of Set 12 | santo antonio do ica
# Processing Record 6 of Set 12 | kenora
# Processing Record 7 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 12 | vyartsilya
# Processing Record 9 of Set 12 | bereda
# Processing Record 10 of Set 12 | beira
# Processing Record 11 of Set 12 | killin
# Processing Record 12 of Set 12 | katangli
# Processing Record 13 of Set 12 | genhe
# Processing Record 14 of Set 12 | okha
# Processing Record 15 of Set 12 | los llanos de aridane
# Processing Record 16 of Set 12 | russkiy kameshkir
# Processing Record 17 of Set 12 | derzhavinsk
# Processing Record 18 of Set 12 | kasongo-lunda
# Processing Record 19 of Set 12 | monte escobedo
# Processing Record 20 of Set 12 | lumeje
# Processing Record 21 of Set 12 | lepley
# Processing Record 22 of Set 12 | pochutla
# Processing Record 23 of Set 12 | zhoucheng
# Processing Record 24 of Set 12 | vrangel
# Processing Record 25 of Set 12 | batsfjord
# Processing Record 26 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 27 of Set 12 | deputatskiy
# Processing Record 28 of Set 12 | jumla
# Processing Record 29 of Set 12 | linhares
# Processing Record 30 of Set 12 | dukat
# Processing Record 31 of Set 12 | goderich
# Processing Record 32 of Set 12 | karratha
# Processing Record 33 of Set 12 | marsh harbour
# Processing Record 34 of Set 12 | norilsk
# Processing Record 35 of Set 12 | mahajanga
# Processing Record 36 of Set 12 | tevaitoa
# Processing Record 37 of Set 12 | haines junction
# Processing Record 38 of Set 12 | pluderhausen
# Processing Record 39 of Set 12 | garh maharaja
# Processing Record 40 of Set 12 | estrela
# Processing Record 41 of Set 12 | powell river
# Processing Record 42 of Set 12 | upington
# Processing Record 43 of Set 12 | tecoanapa
# Processing Record 44 of Set 12 | tautira
# Processing Record 45 of Set 12 | beitbridge
# Processing Record 46 of Set 12 | abu samrah
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | porto nacional
# Processing Record 49 of Set 12 | aswan
# Processing Record 50 of Set 12 | vostok
# Processing Record 1 of Set 13 | san quintin
# Processing Record 2 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 3 of Set 13 | kondopoga
# Processing Record 4 of Set 13 | jilib
# Processing Record 5 of Set 13 | severnoye
# Processing Record 6 of Set 13 | tiznit
# Processing Record 7 of Set 13 | jinchang
# Processing Record 8 of Set 13 | tiarei
# Processing Record 9 of Set 13 | kenai
# Processing Record 10 of Set 13 | sorong
# Processing Record 11 of Set 13 | sao domingos
# Processing Record 12 of Set 13 | borogontsy
# Processing Record 13 of Set 13 | kalmunai
# Processing Record 14 of Set 13 | sal rei
# Processing Record 15 of Set 13 | tarangnan
# Processing Record 16 of Set 13 | tlacotepec
# Processing Record 17 of Set 13 | beaupre
# Processing Record 18 of Set 13 | poya
# Processing Record 19 of Set 13 | ekibastuz
# Processing Record 20 of Set 13 | roseburg
# Processing Record 21 of Set 13 | paramonga
# Processing Record 22 of Set 13 | porterville
# Processing Record 23 of Set 13 | copiapo
# Processing Record 24 of Set 13 | yar-sale
# Processing Record 25 of Set 13 | velim
# Processing Record 26 of Set 13 | kieta
# Processing Record 27 of Set 13 | bar harbor
# Processing Record 28 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 29 of Set 13 | kunashak
# Processing Record 30 of Set 13 | moose factory
# Processing Record 31 of Set 13 | marfino
# Processing Record 32 of Set 13 | eyl
# Processing Record 33 of Set 13 | manali
# Processing Record 34 of Set 13 | bardiyah
# Processing Record 35 of Set 13 | cherdyn
# Processing Record 36 of Set 13 | port augusta
# Processing Record 37 of Set 13 | vanderhoof
# Processing Record 38 of Set 13 | waingapu
# Processing Record 39 of Set 13 | comodoro rivadavia
# Processing Record 40 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 13 | ladybrand
# Processing Record 43 of Set 13 | bria
# Processing Record 44 of Set 13 | nabire
# Processing Record 45 of Set 13 | hamilton
# Processing Record 46 of Set 13 | rijeka
# Processing Record 47 of Set 13 | queimadas
# Processing Record 48 of Set 13 | alta floresta
# Processing Record 49 of Set 13 | presidente franco
# Processing Record 50 of Set 13 | bansda
# City not found. Skipping...
# Processing Record 1 of Set 14 | karasburg
# Processing Record 2 of Set 14 | gazli
# Processing Record 3 of Set 14 | havoysund
# Processing Record 4 of Set 14 | christchurch
# Processing Record 5 of Set 14 | prince rupert
# Processing Record 6 of Set 14 | hadrut
# Processing Record 7 of Set 14 | elk city
# Processing Record 8 of Set 14 | harur
# Processing Record 9 of Set 14 | morondava
# Processing Record 10 of Set 14 | khani
# Processing Record 11 of Set 14 | kamaishi
# Processing Record 12 of Set 14 | humaita
# Processing Record 13 of Set 14 | linxia
# Processing Record 14 of Set 14 | yulara
# Processing Record 15 of Set 14 | la vega
# Processing Record 16 of Set 14 | praya
# Processing Record 17 of Set 14 | kamenka
# Processing Record 18 of Set 14 | cap-aux-meules
# Processing Record 19 of Set 14 | poso
# Processing Record 20 of Set 14 | male
# Processing Record 21 of Set 14 | kokopo
# Processing Record 22 of Set 14 | simplicio mendes
# Processing Record 23 of Set 14 | constitucion
# Processing Record 24 of Set 14 | atar
# Processing Record 25 of Set 14 | dali
# Processing Record 26 of Set 14 | kawalu
# Processing Record 27 of Set 14 | faratsiho
# Processing Record 28 of Set 14 | amantea
# Processing Record 29 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 14 | darhan
# Processing Record 31 of Set 14 | broken hill
# Processing Record 32 of Set 14 | manzanillo
# Processing Record 33 of Set 14 | saint-pierre
# Processing Record 34 of Set 14 | macusani
# Processing Record 35 of Set 14 | nelson bay
# Processing Record 36 of Set 14 | ergani
# Processing Record 37 of Set 14 | san cristobal
# Processing Record 38 of Set 14 | yaan
# Processing Record 39 of Set 14 | sabancuy
# Processing Record 40 of Set 14 | simoes
# Processing Record 41 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 42 of Set 14 | shelkovskaya
# Processing Record 43 of Set 14 | puerto escondido
# Processing Record 44 of Set 14 | gawler
# Processing Record 45 of Set 14 | planeta rica
# Processing Record 46 of Set 14 | sterling
# Processing Record 47 of Set 14 | sovetskiy
# Processing Record 48 of Set 14 | chase
# Processing Record 49 of Set 14 | mackenzie
# Processing Record 50 of Set 14 | bela vista
# Processing Record 1 of Set 15 | egvekinot
# Processing Record 2 of Set 15 | ormara
# Processing Record 3 of Set 15 | ranong
# Processing Record 4 of Set 15 | sao gabriel da cachoeira
# Processing Record 5 of Set 15 | gainesville
# Processing Record 6 of Set 15 | berezovyy
# Processing Record 7 of Set 15 | novoagansk
# Processing Record 8 of Set 15 | alice springs
# Processing Record 9 of Set 15 | vawkavysk
# Processing Record 10 of Set 15 | hirara
# Processing Record 11 of Set 15 | houma
# Processing Record 12 of Set 15 | miracema do tocantins
# Processing Record 13 of Set 15 | porto-vecchio
# Processing Record 14 of Set 15 | guane
# Processing Record 15 of Set 15 | bilibino
# Processing Record 16 of Set 15 | barkot
# Processing Record 17 of Set 15 | matay
# Processing Record 18 of Set 15 | maragogi
# Processing Record 19 of Set 15 | nizhnevartovsk
# Processing Record 20 of Set 15 | barcelos
# Processing Record 21 of Set 15 | foki
# Processing Record 22 of Set 15 | gwadar
# Processing Record 23 of Set 15 | qena
# Processing Record 24 of Set 15 | kattivakkam
# Processing Record 25 of Set 15 | sokolo
# Processing Record 26 of Set 15 | ulladulla
# Processing Record 27 of Set 15 | parrita
# Processing Record 28 of Set 15 | antofagasta
# Processing Record 29 of Set 15 | chinchani
# Processing Record 30 of Set 15 | rockport
# Processing Record 31 of Set 15 | atikokan
# Processing Record 32 of Set 15 | fairbanks
# Processing Record 33 of Set 15 | lodja
# Processing Record 34 of Set 15 | jamsa
# Processing Record 35 of Set 15 | arrifes
# Processing Record 36 of Set 15 | kohlu
# Processing Record 37 of Set 15 | porto belo
# Processing Record 38 of Set 15 | puerto madryn
# Processing Record 39 of Set 15 | hastings
# Processing Record 40 of Set 15 | tarakan
# Processing Record 41 of Set 15 | roald
# Processing Record 42 of Set 15 | batagay-alyta
# Processing Record 43 of Set 15 | basco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tiksi      RU  71.6872  128.8694    -15.92        93         100
# 1    Punta Arenas      CL -53.1500  -70.9167     53.71        62           0
# 2   Half Moon Bay      US  37.4636 -122.4286     48.45        84         100
# 3      Kaitangata      NZ -46.2817  169.8464     51.40        66         100
# 4            Luna      PH  10.9667  123.2333     79.02        88         100
# 5    Quatre Cocos      MU -20.2078   57.7625     78.10        72          55
# 6  Saint-Philippe      RE -21.3585   55.7679     74.79        75          37
# 7          Albany      US  42.6001  -73.9662     30.63        79          19
# 8      Nikolskoye      RU  59.7035   30.7861     28.29        90         100
# 9         Rikitea      PF -23.1203 -134.9692     76.69        84         100
#
#    Wind Speed Current Description
# 0        8.88     overcast clouds
# 1        9.22           clear sky
# 2        8.05                mist
# 3        6.46     overcast clouds
# 4       13.71     overcast clouds
# 5       11.43          light rain
# 6        9.69    scattered clouds
# 7       10.00          few clouds
# 8        6.33     overcast clouds
# 9       17.43     overcast clouds

# %%
# Rename the Description column to Current Description
city_data_df = city_data_df.rename(columns={"Description":"Current Description"})
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tiksi      RU  71.6872  128.8694    -15.92        93         100
# 1   Punta Arenas      CL -53.1500  -70.9167     53.71        62           0
# 2  Half Moon Bay      US  37.4636 -122.4286     48.45        84         100
# 3     Kaitangata      NZ -46.2817  169.8464     51.40        66         100
# 4           Luna      PH  10.9667  123.2333     79.02        88         100
#
#    Wind Speed Current Description
# 0        8.88     overcast clouds
# 1        9.22           clear sky
# 2        8.05                mist
# 3        6.46     overcast clouds
# 4       13.71     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tiksi      RU  71.6872  128.8694    -15.92        93         100
# 1   Punta Arenas      CL -53.1500  -70.9167     53.71        62           0
# 2  Half Moon Bay      US  37.4636 -122.4286     48.45        84         100
# 3     Kaitangata      NZ -46.2817  169.8464     51.40        66         100
# 4           Luna      PH  10.9667  123.2333     79.02        88         100
#
#    Wind Speed Current Description
# 0        8.88     overcast clouds
# 1        9.22           clear sky
# 2        8.05                mist
# 3        6.46     overcast clouds
# 4       13.71     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
